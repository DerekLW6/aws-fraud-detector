# %% [markdown]
# ## Important - You have to convert the time columns to EVENT_Timestamp it's required for AWS Fraud Detector. I did it in excel prior to writing this notebook

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import seaborn as sns
# %matplotlib inline

# importing the data
df = pd.read_csv('creditcard.csv')

# Renaming
df.rename(columns = {'Class':'EVENT_LABEL'}, inplace = True)

#Lowercase
df.columns = map(str.lower, df.columns)

# Fixing two outliers
df.rename(columns = {'event_label':'EVENT_LABEL', 'event_timestamp':'EVENT_TIMESTAMP'}, inplace = True)

df.head(3)
# Out:
#    EVENT_TIMESTAMP        v1        v2        v3        v4        v5  \
# 0  3/29/2021 14:27 -1.359807 -0.072781  2.536347  1.378155 -0.338321
# 1  3/29/2021 14:27  1.191857  0.266151  0.166480  0.448154  0.060018
# 2  3/29/2021 14:27 -1.358354 -1.340163  1.773209  0.379780 -0.503198
#
#          v6        v7        v8        v9  ...       v21       v22       v23  \
# 0  0.462388  0.239599  0.098698  0.363787  ... -0.018307  0.277838 -0.110474
# 1 -0.082361 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288
# 2  1.800499  0.791461  0.247676 -1.514654  ...  0.247998  0.771679  0.909412
#
#         v24       v25       v26       v27       v28  amount  EVENT_LABEL
# 0  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62            0
# 1 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69            0
# 2 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66            0
#
# [3 rows x 31 columns]

# %%
# Determining the distribution
sns.countplot(x=df['EVENT_LABEL'], data=df)

# %%
df['EVENT_LABEL'].value_counts(normalize=True)
# Out:
# 0    0.998168
# 1    0.001832
# Name: EVENT_LABEL, dtype: float64

# %%
# Replacing labels
df['EVENT_LABEL'] = df['EVENT_LABEL'].replace(0,'legit')
df['EVENT_LABEL'] = df['EVENT_LABEL'].replace(1,'fraud')

# %%
df.head(3)
# Out:
#    EVENT_TIMESTAMP        V1        V2        V3        V4        V5  \
# 0  3/29/2021 14:27 -1.359807 -0.072781  2.536347  1.378155 -0.338321
# 1  3/29/2021 14:27  1.191857  0.266151  0.166480  0.448154  0.060018
# 2  3/29/2021 14:27 -1.358354 -1.340163  1.773209  0.379780 -0.503198
#
#          V6        V7        V8        V9  ...       V21       V22       V23  \
# 0  0.462388  0.239599  0.098698  0.363787  ... -0.018307  0.277838 -0.110474
# 1 -0.082361 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288
# 2  1.800499  0.791461  0.247676 -1.514654  ...  0.247998  0.771679  0.909412
#
#         V24       V25       V26       V27       V28  Amount  EVENT_LABEL
# 0  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62        legit
# 1 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69        legit
# 2 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66        legit
#
# [3 rows x 31 columns]

# %%
# Writting to CSV
df.to_csv('fraud.csv')
